# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaXzaviero/MachineLearning2/blob/main/StudentMentalStressAndCopingMechanisms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
import sklearn.metrics
from sklearn.metrics import accuracy_score, classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Path ke file di Google Drive
file_path = "/content/drive/My Drive/content/dataset_mental.csv"

# Baca file CSV
df = pd.read_csv(file_path)

# %%
df.head(50)  # Menampilkan 50 baris pertama
df.tail(50)  # Menampilkan 50 baris terakhir
# Out:
#       Student ID  Age       Gender  Academic Performance (GPA)  \
# 710  830-78-6799   19         Male                           0
# 711  442-22-8487   26         Male                           2
# 712  139-21-3471   23         Male                           3
# 713  822-59-2803   26  Genderfluid                           2
# 714  795-24-8301   24         Male                           1
# 715  889-99-6609   18         Male                           2
# 716  174-93-0351   22         Male                           2
# 717  123-20-9401   19         Male                           1
# 718  792-95-3865   30       Female                           3
# 719  893-18-6851   22         Male                           1
# 720  344-90-2479   30       Female                           2
# 721  697-82-5034   23         Male                           1
# 722  573-17-2120   22       Female                           1
# 723  659-78-0605   25         Male                           2
# ...

# %%
from matplotlib import pyplot as plt
_df_3['Social Media Usage (Hours per day)'].plot(kind='hist', bins=20, title='Social Media Usage (Hours per day)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
print(df.shape) #Output: (Jumlah_baris, Jumlah_kolom)
# Out:
# (760, 20)
